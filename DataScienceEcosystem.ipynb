# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
#  In this notebook, we give an introduction of Data Science Tools and Ecosystem. Focusing more on Jupyter notebook, RStudio and Github. The data science tools are designed to help data scientist explore, manipulate and effectively communicate their findings to interested parties.

# %% [markdown]
#  **Objectives**
# * Python
# * R
# * SQL
# * C
# * C++
# * Java

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. C, C++
# 4. Julia
# 5. Java
# 6. SQL

# %% [markdown]
#  Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. TensorFlow
# 5. Keras
# 6. gigiplot

# %% [markdown]
# | Data Science Tools |
# | -----------        |
# | Jupyter Notebook   |
# | RStudio            |
# | Git                |
# | Github             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Dorisa
